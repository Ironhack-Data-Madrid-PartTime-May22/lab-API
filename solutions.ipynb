# %% [markdown]
# # Lab API

# %% [markdown]
# ### De la web de APIs gratuitas propuesta he elegido la sección de vehicle la API de Mercedes-Benz (https://developer.mercedes-benz.com/products)

# %%
import pandas as pd # manipulacion de  datos mediante dataframes
pd.options.display.max_columns = None # para que se muestren todas las columnas


import requests # para hacer peticiones a la web y obtener datos 


import os  # para acceder a las variables de entorno del sistema operativo 
from dotenv import load_dotenv # para cargar las variables de entorno desde el fichero .env

# %%
load_dotenv()

#api_key es el nombre de la variable que almacena el token  en el archivo .env

token = os.getenv('api_key')

# %%
# funcion para hacer la llamada a la API
def get_api(url):
    """
    Realiza una solicitud HTTP GET a una API utilizando la libreria requests. 
    Si la respuesta tiene un código de estado 200 (éxito), la función devuelve los 
    datos de la respuesta en formato JSON; de lo contrario, devuelve un mensaje 
    de error con el código de estado.

    Args:
        url (str): Endpoint de la API a la que se realiza la solicitud. 

    Returns:
        dict o str: datos de la respuesta en formato JSON o mensaje de error con el código de estado.
    """
    res = requests.get(url) # realizamos la llamada a la API 
    
    if res.status_code == 200: # si la respuesta es correcta 
        
        return res.json() # devolvemos los datos en formato JSON
    
    else: # si la respuesta no es correcta 
        
        return f"Error {res.status_code}" # devolvemos un mensaje de error con el código de estado

# %%
# La mayoría son de pago :(

# Car Configurator:

url = f"https://api.mercedes-benz.com/configurator/v1?apikey={token}"
url = f'https://api.mercedes-benz.com/configurator/v1/markets?country=ES&apikey={token}'

res_api = get_api(url)


#print(res_api[0].keys())

# dict_keys(['marketId', 'language', 'country', 'vbet', 'kernelType', '_links'])

#print(res_api[0]['_links']['models'])

url = res_api[0]['_links']['models']
res_api = get_api(url)


informacion = {"ID":[],"Country":[],"Language":[],"Sales level":[],"Date":[],"Name":[],"Class":[],"Product group":[],"All terrain":[],"Net price":[],"Currency":[]}


for car in range(0, len(res_api)):
    informacion['ID'].append(res_api[car]['vehicleSortId'])
    informacion['Country'].append(res_api[car]['context']['market']['country'])
    informacion['Language'].append(res_api[car]['context']['market']['language'])
    informacion['Sales level'].append(res_api[car]['context']['salesLevel'])
    informacion['Date'].append(res_api[car]['context']['pricingDate'])
    informacion['Name'].append(res_api[car]['name'])
    informacion['Class'].append(res_api[car]['vehicleClass']['className'])
    informacion['Product group'].append(res_api[car]['productGroup'])
    informacion['All terrain'].append(res_api[car]['allTerrain'])
    informacion['Net price'].append(res_api[car]['priceInformation']['netPrice'])
    informacion['Currency'].append(res_api[car]['priceInformation']['currency'])


df = pd.DataFrame(informacion)

df.sample(20)
# Out:
#            ID Country Language Sales level        Date  \
# 175  47650000      ES       es    INTERNET  2023-06-28
# 53   12820000      ES       es    INTERNET  2023-06-28
# 48    9490000      ES       es    INTERNET  2023-06-28
# 25    3880000      ES       es    INTERNET  2023-06-28
# 91   22670000      ES       es    INTERNET  2023-06-28
# 266        86      ES       es    INTERNET  2023-09-26
# 158  40430000      ES       es    INTERNET  2023-06-28
# 9     1220000      ES       es    INTERNET  2023-06-28
# 392       218      ES       es    INTERNET  2023-09-26
# 286       106      ES       es    INTERNET  2023-09-26
# 245        65      ES       es    INTERNET  2023-09-26
# 411       238      ES       es    INTERNET  2023-09-26
# 113  29920000      ES       es    INTERNET  2023-06-28
# 431       269      ES       es    INTERNET  2023-09-26
# 210        30      ES       es    INTERNET  2023-09-26
# 440       278      ES       es    INTERNET  2023-09-26
# 405       231      ES       es    INTERNET  2023-09-26
# 348       171      ES       es    INTERNET  2023-09-26
# 193        13      ES       es    INTERNET  2023-09-26
# 6     1050000      ES       es    INTERNET  2023-06-28
#
#                                                  Name     Class Product group  \
# 175                                     S 580 e Corto   Clase S           PKW
# 53                                       C 200 Estate   Clase C           PKW
# 48                                   CLS 400 d 4MATIC       CLS           PKW
# 25                                    A 250 e Berlina   Clase A           PKW
# 91                                    E 220 d berlina   Clase E           PKW
# 266                  Clase V 250d Avantgarde Compacto   Clase V           VAN
# 158                    Mercedes-AMG EQE 43 4MATIC SUV       EQE           PKW
# 9                          Mercedes-AMG GLA 35 4MATIC       GLA           PKW
# 392         Sprinter 317 CDI tT OM654 TOURER COMPACTO  Sprinter           VAN
# 286                             Clase V 220d Compacto   Clase V           VAN
# 245              Vito 119 CDI Mixto Select Extralarga      Vito           VAN
# 411       Sprinter 419 CDI tT OM654 FURGON LARGO T.E.  Sprinter           VAN
# 113                                      E 450 4MATIC   Clase E           PKW
# 431  Sprinter 215 CDI tD OM654 CHASIS CABINA COMPACTO  Sprinter           VAN
# 210                  Vito 116 CDI Furgón Select Larga      Vito           VAN
# 440     Sprinter 315 CDI tD OM654 CHASIS CABINA MEDIO  Sprinter           VAN
# 405       Sprinter 415 CDI tT OM654 FURGON LARGO T.E.  Sprinter           VAN
# 348         Sprinter 317 CDI tT OM654 FURGON COMPACTO  Sprinter           VAN
# 193                            Citan 113 Tourer Largo     Citan           VAN
# 6                           Mercedes-AMG E 53 4MATIC+   Clase E           PKW
#
#      All terrain  Net price Currency
# 175        False  113521.98      EUR
# 53         False   42315.57      EUR
# 48         False   78072.30      EUR
# 25         False   42530.95      EUR
# 91         False   45086.47      EUR
# 266        False   62774.00      EUR
# 158        False   97326.78      EUR
# 9          False   51199.63      EUR
# 392        False   44517.00      EUR
# 286        False   51569.00      EUR
# 245        False   44896.00      EUR
# 411        False   47131.00      EUR
# 113        False   72503.60      EUR
# 431        False   33228.00      EUR
# 210        False   37992.00      EUR
# 440        False   35164.00      EUR
# 405        False   42904.00      EUR
# 348        False   40105.00      EUR
# 193        False   24183.00      EUR
# 6          False   91487.28      EUR

# %%
df.isnull().sum()
# Out:
# ID               0
# Country          0
# Language         0
# Sales level      0
# Date             0
# Name             0
# Class            0
# Product group    0
# All terrain      0
# Net price        0
# Currency         0
# dtype: int64

# %%
df.size
# Out:
# 4972
