# %%
# Importo las librerias que vamos necesitar para el lab.
import pandas as pd 
pd.options.display.max_columns = None 
import requests  

# Funcion para hacer la llamada a la API
def get_api(url):
    res = requests.get(url) 
    if res.status_code == 200:  
        return res.json() 
    else:  
        return f"Error {res.status_code}"

url = "https://db.ygoprodeck.com/api/v7/cardinfo.php"
res_api = get_api(url)

# Revisamos la informacion y podemos ver que solo hay una lista de diccionarios que tiene como key 'data'
res_api.keys()

# Dentro de ella esta toda la informacion de las cartas, entonces gurdamos esta lista de diccionarios dentro de una variable
diccionario_limpio = res_api["data"]

# Revisamos las keys que estan dentro
res_api["data"][0].keys()
res_api['data'][1000].keys() # Probamos para poder ver todas la diferentes keys que hay, ya que en la informacion dice que no todos tienen las mismas

# Descartamos la informacion que no nos interesa como: 'card_sets', 'card_images'y 'card_prices' 
# y hacemos un diccionario vacio con las keys que si queremos
info = {
    "id_": [],
    "name": [],
    "type": [],
    "frametype": [],
    "desc": [],
    "race": [],
    "archetype": [],
    "atk": [],
    "def": [],
    "level": [],
    "attribute": []
}

# Iteramos por todos los valores que tenemos en la key "data" guardado previamente en la variable diccionario_limpio
for i in diccionario_limpio:
    info["id_"].append(i.get("id", None))
    info["name"].append(i.get("name", None))
    info["type"].append(i.get("type", None))
    info["frametype"].append(i.get("frameType", None))
    info["desc"].append(i.get("desc", None))
    info["race"].append(i.get("race", None))
    info["archetype"].append(i.get("archetype", None))
    info["atk"].append(i.get("atk", None))
    info["def"].append(i.get("def", None))
    info["level"].append(i.get("level", None))
    info["attribute"].append(i.get("attribute", None))
# Uso el metodo 'get' para evitar que se produzcan excepciones si alguna key no está presente en todos los elementos del diccionario,
# al usar este metodo puedo introducir None en su lugar

#Para concluir, hago un DataFrame con mi diccionario "info" que tiene toda la informacion que con anterioridad he limpiado.
df = pd.DataFrame(info)
df



## Link de donde he sacado todo y he revisado la informacion: https://ygoprodeck.com/api-guide/
# Out:
#             id_                           name            type frametype
# 0      34541863       "A" Cell Breeding Device      Spell Card     spell  \
# 1      64163367             "A" Cell Incubator      Spell Card     spell
# 2      91231901  "A" Cell Recombination Device      Spell Card     spell
# 3      73262676         "A" Cell Scatter Burst      Spell Card     spell
# 4      98319530     "Infernoble Arms - Almace"      Spell Card     spell
# ...         ...                            ...             ...       ...
# 12640   2648201             ZW - Sleipnir Mail  Effect Monster    effect
# 12641  95886782              ZW - Sylphid Wing  Effect Monster    effect
# 12642  81471108           ZW - Tornado Bringer  Effect Monster    effect
# 12643  18865703           ZW - Ultimate Shield  Effect Monster    effect
# 12644  76080032             ZW - Unicorn Spear  Effect Monster    effect
#
#                                                     desc        race
# 0      During each of your Standby Phases, put 1 A-Co...  Continuous  \
# 1      Each time an A-Counter(s) is removed from play...  Continuous
# 2      Target 1 face-up monster on the field; send 1 ...  Quick-Play
# 3      Select 1 face-up "Alien" monster you control. ...  Quick-Play
# 4      While this card is equipped to a monster: You ...       Equip
# ...                                                  ...         ...
# 12640  You can target 1 "Utopia" monster you control;...       Beast
# 12641  You can only control 1 "ZW - Sylphid Wing". Yo...       Beast
# 12642  You can target 1 "Utopia" monster you control;...      Dragon
# 12643  When this card is Normal or Special Summoned: ...        Aqua
# 12644  You can target 1 "Number C39: Utopia Ray" you ...       Beast
#
#           archetype     atk     def  level attribute
# 0             Alien     NaN     NaN    NaN      None
# 1             Alien     NaN     NaN    NaN      None
# 2             Alien     NaN     NaN    NaN      None
# 3             Alien     NaN     NaN    NaN      None
# 4      Noble Knight     NaN     NaN    NaN      None
# ...             ...     ...     ...    ...       ...
# 12640        Utopia  1000.0  1000.0    4.0     LIGHT
# 12641        Utopia   800.0  1600.0    4.0     LIGHT
# 12642        Utopia  1300.0  1800.0    5.0      WIND
# 12643        Utopia     0.0  2000.0    4.0     EARTH
# 12644        Utopia  1900.0     0.0    4.0     LIGHT
#
# [12645 rows x 11 columns]
