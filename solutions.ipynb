# %%
# Importo las librerias que vamos necesitar para el lab.
import pandas as pd 
pd.options.display.max_columns = None 
import requests  

# Funcion para hacer la llamada a la API
def get_api(url):
    res = requests.get(url) 
    if res.status_code == 200:  
        return res.json() 
    else:  
        return f"Error {res.status_code}"

url = "https://db.ygoprodeck.com/api/v7/cardinfo.php"
res_api = get_api(url)

# Revisamos la informacion y podemos ver que solo hay una lista de diccionarios que tiene como key 'data'
res_api.keys()

# Dentro de ella esta toda la informacion de las cartas, entonces gurdamos esta lista de diccionarios dentro de una variable
diccionario_limpio = res_api["data"]

# Revisamos las keys que estan dentro
res_api["data"][0].keys()
res_api['data'][1000].keys() # Probamos para poder ver todas la diferentes keys que hay, ya que en la informacion dice que no todos tienen las mismas


# Descartamos la informacion que no nos interesa como: 'card_sets', 'card_images'y 'card_prices' 
# y hacemos un diccionario vacio con las keys que si queremos
info = {
    "id_": [],
    "name": [],
    "type": [],
    "frametype": [],
    "desc": [],
    "race": [],
    "archetype": [],
    "atk": [],
    "def": [],
    "level": [],
    "attribute": [],
    "url_": []
}

# Iteramos por todos los valores que tenemos en la key "data" guardado previamente en la variable diccionario_limpio
# Uso el metodo 'get' para evitar que se produzcan excepciones si alguna key no está presente en todos los elementos del diccionario,
# al usar este metodo puedo introducir None en su lugar
for i in diccionario_limpio:
    info["id_"].append(i.get("id", None))
    info["name"].append(i.get("name", None))
    info["type"].append(i.get("type", None))
    info["frametype"].append(i.get("frameType", None))
    info["desc"].append(i.get("desc", None))
    info["race"].append(i.get("race", None))
    info["archetype"].append(i.get("archetype", None))
    info["atk"].append(i.get("atk", None))
    info["def"].append(i.get("def", None))
    info["level"].append(i.get("level", None))
    info["attribute"].append(i.get("attribute", None))

# Quiero que se pueda ver la informacion mas detallada y la imagen de la carta, asi que busque una pagina que cambiando el nombre me saque la url de cada carta
# Itero para poder pasar los espacios a barras bajas, y los meto dentro del diccionario vacio
name_search = {"name_search": []}

for e in info["name"]:
    n = e.replace(" ", "_")  # Reemplazar espacios por barra baja en cada nombre
    name_search["name_search"].append(n)  # Agregar el nombre modificado a la lista

# Hago un bucle para poder meter los urls dentro de info para que se vea en mi df
for i in name_search["name_search"]:
    url_search = f"https://yugioh.fandom.com/wiki/{i}" # Hacemos cada url diferente con "name_search"
    info["url_"].append(url_search) #Agregamos cada url dentro de "info['url_']" 

# Para concluir, hago un DataFrame con mi diccionario "info" que tiene toda la informacion que con anterioridad he limpiado.
df = pd.DataFrame(info)

# Pongo como indice la columna "id_"
df.set_index('id_', inplace=True)

df


    




## Link de donde he sacado y revisado la informacion: https://ygoprodeck.com/api-guide/
# Out:
#                                    name            type frametype
# id_
# 34541863       "A" Cell Breeding Device      Spell Card     spell  \
# 64163367             "A" Cell Incubator      Spell Card     spell
# 91231901  "A" Cell Recombination Device      Spell Card     spell
# 73262676         "A" Cell Scatter Burst      Spell Card     spell
# 98319530     "Infernoble Arms - Almace"      Spell Card     spell
# ...                                 ...             ...       ...
# 2648201              ZW - Sleipnir Mail  Effect Monster    effect
# 95886782              ZW - Sylphid Wing  Effect Monster    effect
# 81471108           ZW - Tornado Bringer  Effect Monster    effect
# 18865703           ZW - Ultimate Shield  Effect Monster    effect
# 76080032             ZW - Unicorn Spear  Effect Monster    effect
#
#                                                        desc        race
# id_
# 34541863  During each of your Standby Phases, put 1 A-Co...  Continuous  \
# 64163367  Each time an A-Counter(s) is removed from play...  Continuous
# 91231901  Target 1 face-up monster on the field; send 1 ...  Quick-Play
# 73262676  Select 1 face-up "Alien" monster you control. ...  Quick-Play
# 98319530  While this card is equipped to a monster: You ...       Equip
# ...                                                     ...         ...
# 2648201   You can target 1 "Utopia" monster you control;...       Beast
# 95886782  You can only control 1 "ZW - Sylphid Wing". Yo...       Beast
# 81471108  You can target 1 "Utopia" monster you control;...      Dragon
# 18865703  When this card is Normal or Special Summoned: ...        Aqua
# 76080032  You can target 1 "Number C39: Utopia Ray" you ...       Beast
#
#              archetype     atk     def  level attribute
# id_
# 34541863         Alien     NaN     NaN    NaN      None  \
# 64163367         Alien     NaN     NaN    NaN      None
# 91231901         Alien     NaN     NaN    NaN      None
# 73262676         Alien     NaN     NaN    NaN      None
# 98319530  Noble Knight     NaN     NaN    NaN      None
# ...                ...     ...     ...    ...       ...
# 2648201         Utopia  1000.0  1000.0    4.0     LIGHT
# 95886782        Utopia   800.0  1600.0    4.0     LIGHT
# 81471108        Utopia  1300.0  1800.0    5.0      WIND
# 18865703        Utopia     0.0  2000.0    4.0     EARTH
# 76080032        Utopia  1900.0     0.0    4.0     LIGHT
#
#                                                        url_
# id_
# 34541863  https://yugioh.fandom.com/wiki/"A"_Cell_Breedi...
# 64163367  https://yugioh.fandom.com/wiki/"A"_Cell_Incubator
# 91231901  https://yugioh.fandom.com/wiki/"A"_Cell_Recomb...
# 73262676  https://yugioh.fandom.com/wiki/"A"_Cell_Scatte...
# 98319530  https://yugioh.fandom.com/wiki/"Infernoble_Arm...
# ...                                                     ...
# 2648201   https://yugioh.fandom.com/wiki/ZW_-_Sleipnir_Mail
# 95886782   https://yugioh.fandom.com/wiki/ZW_-_Sylphid_Wing
# 81471108  https://yugioh.fandom.com/wiki/ZW_-_Tornado_Br...
# 18865703  https://yugioh.fandom.com/wiki/ZW_-_Ultimate_S...
# 76080032  https://yugioh.fandom.com/wiki/ZW_-_Unicorn_Spear
#
# [12645 rows x 11 columns]

# %%
fila = df.loc[38033121]
fila
# Out:
# name                                        Dark Magician Girl
# type                                            Effect Monster
# frametype                                               effect
# desc         Gains 300 ATK for every "Dark Magician" or "Ma...
# race                                               Spellcaster
# archetype                                        Dark Magician
# atk                                                     2000.0
# def                                                     1700.0
# level                                                      6.0
# attribute                                                 DARK
# url_         https://yugioh.fandom.com/wiki/Dark_Magician_Girl
# Name: 38033121, dtype: object
